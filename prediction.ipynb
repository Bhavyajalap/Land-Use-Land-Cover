# %%
import ee
import geemap

# %%
ee.Authenticate()
ee.Initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
m = geemap.Map()
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %%
roi = ee.Geometry.Point([-74.67680795322963, 41.005682053106966]).buffer(20000)

imageVisParam = {
    "opacity":1,
    "bands":["SR_B4","SR_B3","SR_B2"],
    "min":181.9046945289955,
    "max":183.5943963751086,
    "gamma":1
},
training = ee.FeatureCollection(
        [ee.Feature(
            ee.Geometry.Point([-73.71283731743893, 40.89311166564792]),
            {
              "Class": 0,
              "system:index": "0"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.66339884087643, 40.94395973768035]),
            {
              "Class": 0,
              "system:index": "1"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.89583608913098, 40.97897743187195]),
            {
              "Class": 0,
              "system:index": "2"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.89583608913098, 41.008000502467794]),
            {
              "Class": 0,
              "system:index": "3"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.88753247458231, 41.049001177894056]),
            {
              "Class": 0,
              "system:index": "4"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.92660507319295, 41.192078948234496]),
            {
              "Class": 0,
              "system:index": "5"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.89845260737263, 41.15693359090968]),
            {
              "Class": 0,
              "system:index": "6"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.9461193446336, 41.28565035083167]),
            {
              "Class": 0,
              "system:index": "7"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.96877864639141, 41.25571748238436]),
            {
              "Class": 0,
              "system:index": "8"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.6353825272714, 41.332007504622524]),
            {
              "Class": 0,
              "system:index": "9"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.74181258098234, 41.308801422697215]),
            {
              "Class": 0,
              "system:index": "10"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.65392195598234, 41.26288061925921]),
            {
              "Class": 0,
              "system:index": "11"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.74181258098234, 41.38251659897289]),
            {
              "Class": 0,
              "system:index": "12"
            }),
        ee.Feature(
            ee.Geometry.Point([-74.03214860341923, 40.5517441268682]),
            {
              "Class": 0,
              "system:index": "13"
            }),
        ee.Feature(
            ee.Geometry.Point([-74.07609391591923, 40.50059542194113]),
            {
              "Class": 0,
              "system:index": "14"
            }),
        ee.Feature(
            ee.Geometry.Point([-74.17634416005986, 40.50059542194113]),
            {
              "Class": 0,
              "system:index": "15"
            }),
        ee.Feature(
            ee.Geometry.Point([-74.20243668935673, 40.48806325864273]),
            {
              "Class": 0,
              "system:index": "16"
            }),
        ee.Feature(
            ee.Geometry.Point([-74.08845353505986, 40.47970718276995]),
            {
              "Class": 0,
              "system:index": "17"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.92228532216923, 40.442091969366174]),
            {
              "Class": 0,
              "system:index": "18"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.84263444326298, 40.53400307992874]),
            {
              "Class": 0,
              "system:index": "19"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.8220350780286, 40.48597433719743]),
            {
              "Class": 0,
              "system:index": "20"
            }),
        ee.Feature(
            ee.Geometry.Point([-74.05721682790237, 40.642727780657005]),
            {
              "Class": 0,
              "system:index": "21"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.77688442862257, 40.80820544607082]),
            {
              "Class": 0,
              "system:index": "22"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.89372315962957, 41.11380237362345]),
            {
              "Class": 0,
              "system:index": "23"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.60480351332446, 40.97154327561317]),
            {
              "Class": 0,
              "system:index": "24"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.6185364234807, 40.95287673766638]),
            {
              "Class": 0,
              "system:index": "25"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.63638920668383, 40.93316744254757]),
            {
              "Class": 0,
              "system:index": "26"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.59931034926196, 40.93316744254757]),
            {
              "Class": 0,
              "system:index": "27"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.65012211684008, 40.924867032372276]),
            {
              "Class": 0,
              "system:index": "28"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.65973515394946, 40.88438760232008]),
            {
              "Class": 0,
              "system:index": "29"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.45008328974478, 41.48936000599413]),
            {
              "Class": 0,
              "system:index": "30"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.44905332148306, 41.483444692977365]),
            {
              "Class": 0,
              "system:index": "31"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.4397836071276, 41.463894600815095]),
            {
              "Class": 0,
              "system:index": "32"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.45351651728384, 41.46235092136605]),
            {
              "Class": 0,
              "system:index": "33"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.46015862693548, 41.51413326597258]),
            {
              "Class": 0,
              "system:index": "34"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.45706872215032, 41.50590626588624]),
            {
              "Class": 0,
              "system:index": "35"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.42603007378698, 41.56960993329718]),
            {
              "Class": 0,
              "system:index": "36"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.47752848687291, 41.55753652798723]),
            {
              "Class": 0,
              "system:index": "37"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.46104899468541, 41.53826578375592]),
            {
              "Class": 0,
              "system:index": "38"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.4438828569901, 41.53466794199818]),
            {
              "Class": 0,
              "system:index": "39"
            }),
         ee.Feature(
            ee.Geometry.Point([-73.56066046068533, 41.05241515290707]),
            {
              "Class": 1,
              "system:index": "0"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.54212103197439, 41.0552630221724]),
            {
              "Class": 1,
              "system:index": "1"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.54744253465994, 41.06186442676047]),
            {
              "Class": 1,
              "system:index": "2"
            }),
        ee.Feature(
            ee.Geometry.Point([-73

              "system:index": "54"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.58573010447353, 41.530981915548615]),
            {
              "Class": 1,
              "system:index": "55"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.58598057854549, 41.530823759523564]),
            {
              "Class": 1,
              "system:index": "56"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.58589474785701, 41.53092817020595]),
            {
              "Class": 1,
              "system:index": "57"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.58589474785701, 41.53077958572262]),
            {
              "Class": 1,
              "system:index": "58"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.58749634565312, 41.53077135951398]),
            {
              "Class": 1,
              "system:index": "59"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.58749634565312, 41.53083962811146]),
            {
              "Class": 1,
              "system:index": "60"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.58764118493993, 41.5309360071852]),
            {
              "Class": 1,
              "system:index": "61"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.59318466002635, 41.51522864447491]),
            {
              "Class": 1,
              "system:index": "62"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.59324903304271, 41.51477876504546]),
            {
              "Class": 1,
              "system:index": "63"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.59303445632152, 41.51477876504546]),
            {
              "Class": 1,
              "system:index": "64"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.59271259123973, 41.51479483222179]),
            {
              "Class": 1,
              "system:index": "65"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.59207958991222, 41.51515634263463]),
            {
              "Class": 1,
              "system:index": "66"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.59156460578136, 41.51553391802125]),
            {
              "Class": 1,
              "system:index": "67"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.5914465885847, 41.515236678007724]),
            {
              "Class": 1,
              "system:index": "68"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.59137148673229, 41.514602025842684]),
            {
              "Class": 1,
              "system:index": "69"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.59162812708333, 41.51602578688103]),
            {
              "Class": 1,
              "system:index": "70"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.59292976786413, 41.51640063272891]),
            {
              "Class": 1,
              "system:index": "71"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.59269373347082, 41.51640063272891]),
            {
              "Class": 1,
              "system:index": "72"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.59242551256933, 41.51640063272891]),
            {
              "Class": 1,
              "system:index": "73"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.59228603770056, 41.51640063272891]),
            {
              "Class": 1,
              "system:index": "74"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.59297268320837, 41.51703698169583]),
            {
              "Class": 1,
              "system:index": "75"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.59327309061804, 41.51717354780264]),
            {
              "Class": 1,
              "system:index": "76"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.5931765310935, 41.516972715192914]),
            {
              "Class": 1,
              "system:index": "77"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.59259717394629, 41.516972715192914]),
            {
              "Class": 1,
              "system:index": "78"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.59259717394629, 41.51719764767393]),
            {
              "Class": 1,
              "system:index": "79"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.59233968188086, 41.517020915076095]),
            {
              "Class": 1,
              "system:index": "80"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.59192125727454, 41.51696468187557]),
            {
              "Class": 1,
              "system:index": "81"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.78327797006712, 40.64989328627552]),
            {
              "Class": 1,
              "system:index": "82"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.78298829149351, 40.649673505527225]),
            {
              "Class": 1,
              "system:index": "83"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.78296683382139, 40.649266502230105]),
            {
              "Class": 1,
              "system:index": "84"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.78292391847715, 40.649062999650624]),
            {
              "Class": 1,
              "system:index": "85"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.78248403619871, 40.64933162292445]),
            {
              "Class": 1,
              "system:index": "86"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.77519996785742, 40.65385167619]),
            {
              "Class": 1,
              "system:index": "87"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.7745669665299, 40.653843536658066]),
            {
              "Class": 1,
              "system:index": "88"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.77450259351355, 40.65363190847941]),
            {
              "Class": 1,
              "system:index": "89"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.77621752537172, 40.65452039041398]),
            {
              "Class": 1,
              "system:index": "90"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.7758527449457, 40.65515526448184]),
            {
              "Class": 1,
              "system:index": "91"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.77958002996762, 40.65578537066954]),
            {
              "Class": 1,
              "system:index": "92"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.77989116621335, 40.655842345713914]),
            {
              "Class": 1,
              "system:index": "93"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.78023448896725, 40.65605396688135]),
            {
              "Class": 1,
              "system:index": "94"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.78060999822934, 40.65621675193795]),
            {
              "Class": 1,
              "system:index": "95"
            }),
        ee.Feature(
            ee.Geometry.Point([-73.

              "system:index": "30"
            }),
        ee.Feature(
            ee.Geometry.Point([-74.87240070666054, 41.2055597775128]),
            {
              "Class": 3,
              "system:index": "31"
            }),
         ee.Feature(
            ee.Geometry.Point([-75.51689027233472, 40.829969719302426]),
            {
              "Class": 4,
              "system:index": "0"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.51677225513806, 40.82991289322358]),
            {
              "Class": 4,
              "system:index": "1"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.51660059376111, 40.82988042115667]),
            {
              "Class": 4,
              "system:index": "2"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.51760373993268, 40.830359382531135]),
            {
              "Class": 4,
              "system:index": "3"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.51755009575238, 40.83032285170075]),
            {
              "Class": 4,
              "system:index": "4"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.51832999266239, 40.82972456629729]),
            {
              "Class": 4,
              "system:index": "5"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.51843191660495, 40.82972456629729]),
            {
              "Class": 4,
              "system:index": "6"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.51863040007206, 40.829716448258985]),
            {
              "Class": 4,
              "system:index": "7"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.5192151216373, 40.83038212409857]),
            {
              "Class": 4,
              "system:index": "8"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.5191239265308, 40.83038212409857]),
            {
              "Class": 4,
              "system:index": "9"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.51904882467838, 40.83037400614077]),
            {
              "Class": 4,
              "system:index": "10"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.52220846689792, 40.830495775403286]),
            {
              "Class": 4,
              "system:index": "11"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.52220846689792, 40.83040647796595]),
            {
              "Class": 4,
              "system:index": "12"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.52221383131595, 40.83036994716149]),
            {
              "Class": 4,
              "system:index": "13"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.52221383131595, 40.83031718040841]),
            {
              "Class": 4,
              "system:index": "14"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.52221383131595, 40.83024005969371]),
            {
              "Class": 4,
              "system:index": "15"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.52222992457004, 40.830146702919095]),
            {
              "Class": 4,
              "system:index": "16"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.52194561041446, 40.830459244648004]),
            {
              "Class": 4,
              "system:index": "17"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.52176858461948, 40.83061348547779]),
            {
              "Class": 4,
              "system:index": "18"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.52167738951297, 40.83070684159522]),
            {
              "Class": 4,
              "system:index": "19"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.52171494043918, 40.83061348547779]),
            {
              "Class": 4,
              "system:index": "20"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.52115704096408, 40.83063783926024]),
            {
              "Class": 4,
              "system:index": "21"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.52123750723453, 40.83062566237014]),
            {
              "Class": 4,
              "system:index": "22"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.52096392191501, 40.83063378029712]),
            {
              "Class": 4,
              "system:index": "23"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.5208888200626, 40.830572895820524]),
            {
              "Class": 4,
              "system:index": "24"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.52080298937412, 40.83053230613841]),
            {
              "Class": 4,
              "system:index": "25"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.52021826780887, 40.830410536943]),
            {
              "Class": 4,
              "system:index": "26"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.52006806410404, 40.83033747531839]),
            {
              "Class": 4,
              "system:index": "27"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.51948870695682, 40.82986663180657]),
            {
              "Class": 4,
              "system:index": "28"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.51957990206333, 40.83002899201591]),
            {
              "Class": 4,
              "system:index": "29"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.51973547018619, 40.830162938889345]),
            {
              "Class": 4,
              "system:index": "30"
            }),
        ee.Feature(
            ee.Geometry.Point([-75.52004124201389, 40.830199469807845]),
            {
              "Class": 4,
              "system:index": "31"
            })
        ])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# # Random Forest Supervised Classification

# #Landsat 9 Data
# dataSet = ee.ImageCollection("LANDSAT/LC08/C02/T1") \
# .filterDate('2022-01-01', '2022-05-30') \
# .filterBounds(roi) \
# .filterMetadata('CLOUD_COVER', 'less_than', 10)

# #Scaling Factors
# def applyScaleFactors(image):
#   opticalBands = image.select('B.').multiply(0.0000275).add(-0.2)
#   thermalBands = image.select('B.').multiply(0.00341802).add(149.0)
#   return image.addBands(opticalBands, None, True).addBands(thermalBands, None, True)

# rescale = dataSet.map(applyScaleFactors)
# image = rescale.median()

# mapOptions = {
#   'bands': ['B4', 'B3', 'B2'],
#   'min': 174.17200829,
#   'max': 196.77195653,
# }

# #Create map layers
# m.addLayer(image, mapOptions, 'Landsat 9')
# m.centerObject(roi)

# #Train
# # print(training)

# # Export.table.toAsset(training)

# label = 'Class'
# bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7']
# input = image.select(bands)

# trainImage = input.sampleRegions(**{
#   'collection': training,
#   'properties': [label],
#   'scale': 20
# })

# trainingData = trainImage.randomColumn()
# trainSet = trainingData.filter(ee.Filter.lessThan('random', 0.8))
# testSet = trainingData.filter(ee.Filter.greaterThan('random', 0.8))

# #Classification Model
# classifier = ee.Classifier.smileRandomForest(10) \
# .train(**{
#   'features':trainSet,
#   'classProperty':label,
#   'inputProperties':bands
# })

# classify = input.classify(classifier)

# #Classification Colors
# palette = [
#   '#0c2c84', #water
#   '#e31a1c', #urban
#   '#005a32', #forest
#   'FF8000', #crop
#   '969696' #barren
#   ]
# m.addLayer(classify, {'palette': palette, 'min':1, 'max':5}, 'classification')

# #Assess Accuracy
# confusionMatrix = ee.ConfusionMatrix(testSet.classify(classifier) \
# .errorMatrix(**{
#   'actual': 'Class',
#   'predicted': 'classification'
# }))

# print ('Confusion Matrix: ', confusionMatrix)
# print('Overall Accuracy: ', confusionMatrix.accuracy())
# print('Producers Accuracy: ', confusionMatrix.producersAccuracy())
# print('Consumers Accuracy: ', confusionMatrix.consumersAccuracy())


# Random Forest Supervised Classification

# Landsat 9 Data
dataSet = ee.ImageCollection("LANDSAT/LC09/C02/T1_L2") \
    .filterDate('2023-01-01', '2023-05-30') \
    .filterBounds(roi) \
    .filterMetadata('CLOUD_COVER', 'less_than', 10)

# Scaling Factors
def applyScaleFactors(image):
    opticalBands = image.select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B6', 'SR_B7']) \
                        .multiply(0.0000275).add(-0.2)
    thermalBands = image.select(['ST_B10']) \
                        .multiply(0.00341802).add(149.0)
    return image.addBands(opticalBands, None, True).addBands(thermalBands, None, True)

rescale = dataSet.map(applyScaleFactors)
image = rescale.median()

# Train
label = 'Class'
bands = ['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B6', 'SR_B7']
# input = image.select(bands)

trainImage = image.select(bands).sampleRegions(collection=training, properties=[label], scale=20)

trainingData = trainImage.randomColumn()
trainSet = trainingData.filter(ee.Filter.lessThan('random', 0.8))
testSet = trainingData.filter(ee.Filter.greaterThan('random', 0.8))

# Classification Model
classifier = ee.Classifier.smileRandomForest(10) \
    .train(features=trainSet,
           classProperty=label,
           inputProperties=bands)

classify_1 = image.classify(classifier)

pred = testSet.classify(classifier)

# Classification Colors
palette = [
    '#0c2c84',  # water
    '#e31a1c',  # urban
    '#005a32',  # forest
    '#FF8000',  # crop
    '#969696'   # barren
]
# Add the classified image to the map
m.addLayer(classify_1, {'palette': palette, 'min': 0, 'max': 4}, 'Classification')

# Assess Accuracy
confusionMatrix = ee.ConfusionMatrix(testSet.classify(classifier) \
    .errorMatrix({
        'actual': 'Class',
        'predicted': 'classification'  # Change 'classification' to 'Class'
    }))

# confusionMatrix = ee.ConfusionMatrix(pred.errorMatrix('Class', 'classification'))

# print('Confusion Matrix: ', confusionMatrix)
print('Overall Accuracy: ', confusionMatrix.accuracy().getInfo())
print('Producers Accuracy: ', confusionMatrix.producersAccuracy().getInfo())
print('Consumers Accuracy: ', confusionMatrix.consumersAccuracy().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# Cell In[5], line 133
# ...

# %%
m
